# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile
import geopandas as gpd
import urllib
import glob
import matplotlib.pyplot as plt
from fiona.crs import from_epsg
from shapely.geometry import Point, LineString

# %matplotlib inline

# %%
# !mkdir download_data
# !wget http://streetscore.media.mit.edu/static/files/streetscore_data.zip -O streetscore_data.zip
urllib.request.urlretrieve('https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=Shapefile', 'download_data/precinct.zip')
urllib.request.urlretrieve('http://www1.nyc.gov/assets/nypd/downloads/excel/analysis_and_planning/c-summonses/criminal-court-summons-2007-through-q1-2017.xlsx', 'download_data/crime.xlsx')
# !mv streetscore_data.zip download_data
zf = ZipFile('download_data/streetscore_data.zip')
zf2 = ZipFile('download_data/precinct.zip')
zf.extractall('download_data/')
zf2.extractall('download_data/')
# Out:
# mkdir: download_data: File exists
# --2018-12-10 11:49:10--  http://streetscore.media.mit.edu/static/files/streetscore_data.zip
# Resolving streetscore.media.mit.edu (streetscore.media.mit.edu)... 18.85.28.79
# Connecting to streetscore.media.mit.edu (streetscore.media.mit.edu)|18.85.28.79|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4754382 (4.5M) [application/zip]
# Saving to: ‘streetscore_data.zip’
#
# streetscore_data.zi 100%[===================>]   4.53M  4.58MB/s    in 1.0s
#
# 2018-12-10 11:49:11 (4.58 MB/s) - ‘streetscore_data.zip’ saved [4754382/4754382]

# %%
# ss refers to safety score
ss = pd.read_csv('download_data/streetscore_dataset/streetscore_newyorkcity.csv')
ss.head()
# Out:
#     latitude  longitude    q-score
# 0  40.700909 -74.013504  11.062166
# 1  40.701000 -74.013878  10.818611
# 2  40.701080 -74.012878  12.677955
# 3  40.701187 -74.013268  11.417325
# 4  40.701244 -74.012115  25.199091

# %%
geometry = [Point(xy) for xy in zip(ss.longitude, ss.latitude)]
linkNYC = ss.drop(['longitude', 'latitude'], axis=1)
crs = {'init': 'epsg:4326'}
linkNYC = gpd.GeoDataFrame(ss, crs=crs, geometry=geometry)

# %%
#cs refers to crime statistics
cs = pd.read_excel('download_data/crime.xlsx', skiprows=[0,1,2])

# %%
cs['index'] = list(cs.index)
precinct_name = cs['Precinct'].unique()
def write_precinct(x):
    return precinct_name[int(x['index'] / 250)]
cs['Precinct'] = cs.apply(write_precinct, axis=1)

# %%
cs.head()
# Out:
#    Precinct                       Violation                  Law  CY2007  \
# 0  CITYWIDE                  ACCEPT ON HAIL  Administrative Code    5547
# 1  CITYWIDE         AFTER HOURS CONSUMPTION                  ABC     232
# 2  CITYWIDE  AGGRAVATED UNLICENSED OPERATOR                  VTL     301
# 3  CITYWIDE                   ANGLE PARKING         Traffic Regs       0
# 4  CITYWIDE        BARE HAND CONTACT (FOOD)          Health Code       0
#
#    CY2008  CY2009  CY2010  CY2011  CY2012  CY2013  CY2014  CY2015  CY2016  \
# 0    3782    4606    4996    4223    3161    3514    2935    2118    2606
# 1     238     209     161     370     398     282     219     127     100
# 2     425     572     360     549     274     307     428     326     253
# 3       0       0       0       0       0       0       0       0       0
# 4      30      75     145     254     267     222      26      28      37
#
#    2017 YTD 03-31  index
# 0             937      0
# 1              16      1
# 2              81      2
# 3               0      3
# 4              10      4

# %%
# pp refers to police precinct
ppshp = gpd.read_file(glob.glob('download_data/*.shp')[0])
ppshp['precinct'] = ppshp['precinct'].astype('int')
ppshp.head()
# Out:
#    precinct    shape_area    shape_leng  \
# 0         1  4.730176e+07  80586.154615
# 1         5  1.808880e+07  18676.124259
# 2         6  2.213214e+07  27175.185625
# 3        71  4.533179e+07  29978.094261
# 4        72  1.046213e+08  87968.194520
#
#                                             geometry
# 0  (POLYGON ((-74.0438776157395 40.69018767637665...
# 1  POLYGON ((-73.98863862848766 40.72293372026369...
# 2  POLYGON ((-73.99968392160721 40.73855224865976...
# 3  POLYGON ((-73.92854313809303 40.66457328584737...
# 4  POLYGON ((-73.99840899113158 40.67186872303234...

# %%
ppshp.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/geopandas/plotting.py in plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#      81     try:
# ---> 82         from descartes.patch import PolygonPatch
#      83     except ImportError:
#
# ModuleNotFoundError: No module named 'descartes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-59-cb210cdf65e6> in <module>()
# ----> 1 ppshp.plot()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     532         from there.
#     533         """
# --> 534         return plot_dataframe(self, *args, **kwargs)
#     535
#     536     plot.__doc__ = plot_dataframe.__doc__
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, **style_kwds)
#     412         return plot_series(df.geometry, cmap=cmap, color=color, ax=ax,
#     413                            figsize=figsize, markersize=markersize,
# --> 414                            **style_kwds)
#     415
#     416     # To accept pd.Series and np.arrays as column
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, **style_kwds)
#     292         values_ = values[poly_idx] if cmap else None
#     293         plot_polygon_collection(ax, polys, values_, facecolor=facecolor,
# --> 294                                 cmap=cmap, **style_kwds)
#     295
#     296     # plot all LineStrings and MultiLineString components in same collection
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/geopandas/plotting.py in plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#      82         from descartes.patch import PolygonPatch
#      83     except ImportError:
# ---> 84         raise ImportError("The descartes package is required"
#      85                           " for plotting polygons in geopandas.")
#      86     from matplotlib.collections import PatchCollection
#
# ImportError: The descartes package is required for plotting polygons in geopandas.

# %%
# as the safety score was collected in 2011, so first explore the crime statistics in 2011
cs_11 = cs[['Precinct', 'Violation', 'CY2011']]
